# %%
# !pip install stable_baselines3
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.4.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting gymnasium<1.1.0,>=0.29.1 (from stable_baselines3)
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.5.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.8.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium<1.1.0,>=0.29.1->stable_baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13->stable_baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (3.0.2)
# Downloading stable_baselines3-2.4.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 11.5 MB/s eta 0:00:00
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 26.0 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium, stable_baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-1.0.0 stable_baselines3-2.4.0

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.monitor import Monitor
from gym.spaces import Box, MultiDiscrete
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/lite/python/util.py:55: DeprecationWarning: jax.xla_computation is deprecated. Please use the AOT APIs; see https://jax.readthedocs.io/en/latest/aot.html. For example, replace xla_computation(f)(*xs) with jit(f).lower(*xs).compiler_ir('hlo'). See CHANGELOG.md for 0.4.30 for more examples.
#   from jax import xla_computation as _xla_computation

# %%
class SolventSwitchEnv(gym.Env):
    def __init__(self):
        super(SolventSwitchEnv, self).__init__()

        # Action space: Jacket Temperature and Solvent Flowrate increments (discrete changes)
        self.action_space = MultiDiscrete([7])

        # Observation space: Continuous states as described (14 variables)
        self.observation_space = Box(low=np.array([-np.inf]*14), high=np.array([np.inf]*14), dtype=np.float32)

        # Initial state and constraints
        self.state = None
        self.done = False
        self.constraints = {
            'volume': (500, 1200),
            'jacket_temp': (20, 80),
            'flowrate': (0, 90),
            'condenser_load': (0, 160)
        }

    def reset(self):
        # Initialize the state based on Table 1
        self.state = np.array([1139.48, 0.0, 69.55, 13.45, 17.0, 22.72, 23.86] + [0.0]*7)
        # 8: condenser load, 7: Flow rate, 6: Jacket temperature, 0: Volume, 1: x_crys, 2: x_reac, 3: x_imp, 9: Inert Gas, 4: x_api ,5: T_Reb
        self.done = False
        return self.state

    def step(self, action):
        # Simulate state transition logic based on the document's dynamics
        next_state = self.state.copy()
        if action == 0:
            next_state[7] += 0
            next_state[6] += 0
        elif action == 1:
            next_state[7] +=  0.05
            next_state[6]+=1
        elif action == 2:
            next_state[7] -= 0.05
            next_state[6]-=1
        elif action == 3:
            next_state[7] += 0.1
            next_state[6]+=5
        elif action == 4:
            next_state[7] -= 0.1
            next_state[6]-=5
        elif action == 5:
            next_state[6]+=10
        elif action == 6:
            next_state[6]-=10


        # Reward Calculation: Reward is exponential decay based on reaction solvent amount
        reaction_solvent_amount = next_state[2] * next_state[0]
        reward = np.exp(-reaction_solvent_amount)

        # Logarithmic constraint penalties
        for key, (min_val, max_val) in self.constraints.items():
            if key == 'volume':
                value = next_state[0]
            elif key == 'jacket_temp':
                value = next_state[6]
            elif key == 'flowrate':
                value = next_state[7]
            elif key == 'condenser_load':
                value = next_state[8]

            if value < min_val or value > max_val:
                reward -= 100 * np.log(abs(value - min_val if value < min_val else value - max_val) + 1e-6)

        # Check termination conditions
        if next_state[2] <= 10.62 and next_state[3] <= 6.09 and next_state[1] >= 48.07:
            self.done = True

        self.state = next_state
        return next_state, reward, self.done, {}

# %%
# !pip install shimmy
# Out:
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from shimmy) (1.26.4)
# Requirement already satisfied: gymnasium>=1.0.0a1 in /usr/local/lib/python3.10/dist-packages (from shimmy) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=1.0.0a1->shimmy) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=1.0.0a1->shimmy) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=1.0.0a1->shimmy) (0.0.4)
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Installing collected packages: shimmy
# Successfully installed shimmy-2.0.0

# %%
env = DummyVecEnv([lambda: SolventSwitchEnv()])
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
model = PPO(
    "MlpPolicy", env, verbose=1, learning_rate=0.001, gamma=0.998,
    n_steps=32, batch_size=64, clip_range=0.2, policy_kwargs={"net_arch": [16, 16]}
)

# Train PPO Model
model.learn(total_timesteps=100000)
model.save("ppo_solvent")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1146 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 32   |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 64           |
# | train/                  |              |
# |    approx_kl            | 0.0073076505 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.0389      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0192      |
# |    value_loss           | 0.000192     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 518          |
# |    iterations           | 3            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 96           |
# | train/                  |              |
# |    approx_kl            | 0.0022564493 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.022       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00683     |
# |    value_loss           | 6.03e-05     |
# ------------------------------------------
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# |    time_elapsed         | 252           |
# |    total_timesteps      | 91136         |
# | train/                  |               |
# |    approx_kl            | 3.2726675e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.56e+08      |
# |    n_updates            | 28470         |
# |    policy_gradient_loss | -0.000351     |
# |    value_loss           | 3.13e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 2849         |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 91168        |
# | train/                  |              |
# |    approx_kl            | 2.861023e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.56e+08     |
# |    n_updates            | 28480        |
# |    policy_gradient_loss | -0.000176    |
# |    value_loss           | 3.13e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2850          |
# |    time_elapsed         | 252           |
# |    total_timesteps      | 91200         |
# | train/                  |               |
# |    approx_kl            | 1.8533319e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.56e+08      |
# |    n_updates            | 28490         |
# |    policy_gradient_loss | -0.000235     |
# |    value_loss           | 3.13e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2851          |
# |    time_elapsed         | 252           |
# |    total_timesteps      | 91232         |
# | train/                  |               |
# |    approx_kl            | 1.4342368e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28500         |
# |    policy_gradient_loss | -7.93e-05     |
# |    value_loss           | 3.13e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2852          |
# |    time_elapsed         | 252           |
# |    total_timesteps      | 91264         |
# | train/                  |               |
# |    approx_kl            | 1.1399388e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28510         |
# |    policy_gradient_loss | -0.000151     |
# |    value_loss           | 3.13e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2853          |
# |    time_elapsed         | 253           |
# |    total_timesteps      | 91296         |
# | train/                  |               |
# |    approx_kl            | 2.3022294e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28520         |
# |    policy_gradient_loss | -0.00028      |
# |    value_loss           | 3.13e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2854          |
# |    time_elapsed         | 253           |
# |    total_timesteps      | 91328         |
# | train/                  |               |
# |    approx_kl            | 2.7008355e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28530         |
# |    policy_gradient_loss | -0.000205     |
# |    value_loss           | 3.13e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 2855         |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 91360        |
# | train/                  |              |
# |    approx_kl            | 1.206994e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28540        |
# |    policy_gradient_loss | -0.000205    |
# |    value_loss           | 3.13e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2856          |
# |    time_elapsed         | 253           |
# |    total_timesteps      | 91392         |
# | train/                  |               |
# |    approx_kl            | 1.6931444e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28550         |
# |    policy_gradient_loss | -9.52e-05     |
# |    value_loss           | 3.13e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 2857         |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 91424        |
# | train/                  |              |
# |    approx_kl            | 2.335757e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28560        |
# |    policy_gradient_loss | -0.00028     |
# |    value_loss           | 3.13e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2858          |
# |    time_elapsed         | 253           |
# |    total_timesteps      | 91456         |
# | train/                  |               |
# |    approx_kl            | 6.0759485e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28570         |
# |    policy_gradient_loss | -0.000663     |
# |    value_loss           | 3.13e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 2859         |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 91488        |
# | train/                  |              |
# |    approx_kl            | 2.650544e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28580        |
# |    policy_gradient_loss | -0.000189    |
# |    value_loss           | 3.13e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2860          |
# |    time_elapsed         | 253           |
# |    total_timesteps      | 91520         |
# | train/                  |               |
# |    approx_kl            | 1.0617077e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28590         |
# |    policy_gradient_loss | 2.56e-05      |
# |    value_loss           | 3.13e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 2861         |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 91552        |
# | train/                  |              |
# |    approx_kl            | 6.891787e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28600        |
# |    policy_gradient_loss | -0.000113    |
# |    value_loss           | 3.13e+08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 2862         |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 91584        |
# | train/                  |              |
# |    approx_kl            | 1.264736e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28610        |
# |    policy_gradient_loss | -0.000149    |
# |    value_loss           | 3.13e+08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 2863         |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 91616        |
# | train/                  |              |
# |    approx_kl            | 7.022172e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28620        |
# |    policy_gradient_loss | -3.12e-05    |
# |    value_loss           | 3.13e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2864          |
# |    time_elapsed         | 253           |
# |    total_timesteps      | 91648         |
# | train/                  |               |
# |    approx_kl            | 1.8626451e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28630         |
# |    policy_gradient_loss | -0.000188     |
# |    value_loss           | 3.13e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2865          |
# |    time_elapsed         | 253           |
# |    total_timesteps      | 91680         |
# | train/                  |               |
# |    approx_kl            | 1.9930303e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28640         |
# |    policy_gradient_loss | -0.00027      |
# |    value_loss           | 3.13e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 2866         |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 91712        |
# | train/                  |              |
# |    approx_kl            | 2.188608e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28650        |
# |    policy_gradient_loss | -0.000127    |
# |    value_loss           | 3.14e+08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 2867         |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 91744        |
# | train/                  |              |
# |    approx_kl            | 2.188608e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28660        |
# |    policy_gradient_loss | -0.000286    |
# |    value_loss           | 3.14e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2868          |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 91776         |
# | train/                  |               |
# |    approx_kl            | 2.3078173e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28670         |
# |    policy_gradient_loss | -0.000243     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2869          |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 91808         |
# | train/                  |               |
# |    approx_kl            | 8.1025064e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28680         |
# |    policy_gradient_loss | -6.26e-06     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2870          |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 91840         |
# | train/                  |               |
# |    approx_kl            | 2.8852373e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28690         |
# |    policy_gradient_loss | -0.000414     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 2871         |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 91872        |
# | train/                  |              |
# |    approx_kl            | 5.327165e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28700        |
# |    policy_gradient_loss | 9.73e-05     |
# |    value_loss           | 3.14e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2872          |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 91904         |
# | train/                  |               |
# |    approx_kl            | 8.8103116e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28710         |
# |    policy_gradient_loss | -0.000163     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2873          |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 91936         |
# | train/                  |               |
# |    approx_kl            | 1.1175871e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28720         |
# |    policy_gradient_loss | -0.000175     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 2874         |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 91968        |
# | train/                  |              |
# |    approx_kl            | 6.146729e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28730        |
# |    policy_gradient_loss | -8.32e-06    |
# |    value_loss           | 3.14e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2875          |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 92000         |
# | train/                  |               |
# |    approx_kl            | 1.9241124e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28740         |
# |    policy_gradient_loss | -0.000298     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2876          |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 92032         |
# | train/                  |               |
# |    approx_kl            | 2.9429793e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28750         |
# |    policy_gradient_loss | -0.00035      |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2877          |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 92064         |
# | train/                  |               |
# |    approx_kl            | 3.0510128e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28760         |
# |    policy_gradient_loss | -0.000562     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2878          |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 92096         |
# | train/                  |               |
# |    approx_kl            | 3.8016587e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28770         |
# |    policy_gradient_loss | -0.00035      |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 2879         |
# |    time_elapsed         | 255          |
# |    total_timesteps      | 92128        |
# | train/                  |              |
# |    approx_kl            | 9.946525e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28780        |
# |    policy_gradient_loss | -4.17e-05    |
# |    value_loss           | 3.14e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2880          |
# |    time_elapsed         | 255           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 5.9977174e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28790         |
# |    policy_gradient_loss | -6.91e-05     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2881          |
# |    time_elapsed         | 255           |
# |    total_timesteps      | 92192         |
# | train/                  |               |
# |    approx_kl            | 1.7546117e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28800         |
# |    policy_gradient_loss | -0.000314     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 2882         |
# |    time_elapsed         | 255          |
# |    total_timesteps      | 92224        |
# | train/                  |              |
# |    approx_kl            | 5.405396e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28810        |
# |    policy_gradient_loss | -0.000491    |
# |    value_loss           | 3.14e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2883          |
# |    time_elapsed         | 255           |
# |    total_timesteps      | 92256         |
# | train/                  |               |
# |    approx_kl            | 4.0400773e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28820         |
# |    policy_gradient_loss | -0.000365     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2884          |
# |    time_elapsed         | 255           |
# |    total_timesteps      | 92288         |
# | train/                  |               |
# |    approx_kl            | 2.4419278e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28830         |
# |    policy_gradient_loss | -0.00024      |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2885          |
# |    time_elapsed         | 255           |
# |    total_timesteps      | 92320         |
# | train/                  |               |
# |    approx_kl            | 4.0978193e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28840         |
# |    policy_gradient_loss | 7.57e-05      |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2886          |
# |    time_elapsed         | 255           |
# |    total_timesteps      | 92352         |
# | train/                  |               |
# |    approx_kl            | 1.5869737e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28850         |
# |    policy_gradient_loss | -0.000219     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2887          |
# |    time_elapsed         | 255           |
# |    total_timesteps      | 92384         |
# | train/                  |               |
# |    approx_kl            | 1.5068799e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28860         |
# |    policy_gradient_loss | -9.5e-05      |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2888          |
# |    time_elapsed         | 255           |
# |    total_timesteps      | 92416         |
# | train/                  |               |
# |    approx_kl            | 2.2649765e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28870         |
# |    policy_gradient_loss | -0.000323     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 2889        |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 92448       |
# | train/                  |             |
# |    approx_kl            | 4.42937e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.57e+08    |
# |    n_updates            | 28880       |
# |    policy_gradient_loss | -0.000713   |
# |    value_loss           | 3.14e+08    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2890          |
# |    time_elapsed         | 256           |
# |    total_timesteps      | 92480         |
# | train/                  |               |
# |    approx_kl            | 2.3022294e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28890         |
# |    policy_gradient_loss | 8.44e-06      |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2891          |
# |    time_elapsed         | 256           |
# |    total_timesteps      | 92512         |
# | train/                  |               |
# |    approx_kl            | 3.9916486e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28900         |
# |    policy_gradient_loss | -0.000591     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2892          |
# |    time_elapsed         | 256           |
# |    total_timesteps      | 92544         |
# | train/                  |               |
# |    approx_kl            | 6.2230974e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28910         |
# |    policy_gradient_loss | -0.000466     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 2893          |
# |    time_elapsed         | 256           |
# |    total_timesteps      | 92576         |
# | train/                  |               |
# |    approx_kl            | 5.1725656e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28920         |
# |    policy_gradient_loss | -0.000522     |
# |    value_loss           | 3.14e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 2894         |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 92608        |
# | train/                  |              |
# |    approx_kl            | 5.412847e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28930        |
# |    policy_gradient_loss | -0.000658    |
# |    value_loss           | 3.15e+08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 2895         |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 92640        |
# | train/                  |              |
# |    approx_kl            | 3.412366e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28940        |
# |    policy_gradient_loss | -0.000278    |
# |    value_loss           | 3.15e+08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 2896         |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 92672        |
# | train/                  |              |
# |    approx_kl            | 3.406778e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28950        |
# |    policy_gradient_loss | -0.000457    |
# |    value_loss           | 3.15e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2897          |
# |    time_elapsed         | 256           |
# |    total_timesteps      | 92704         |
# | train/                  |               |
# |    approx_kl            | 1.5795231e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28960         |
# |    policy_gradient_loss | -3.32e-05     |
# |    value_loss           | 3.15e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 2898         |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 92736        |
# | train/                  |              |
# |    approx_kl            | 2.015382e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28970        |
# |    policy_gradient_loss | -0.000167    |
# |    value_loss           | 3.15e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2899          |
# |    time_elapsed         | 257           |
# |    total_timesteps      | 92768         |
# | train/                  |               |
# |    approx_kl            | 1.2256205e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 28980         |
# |    policy_gradient_loss | -0.000187     |
# |    value_loss           | 3.15e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 2900         |
# |    time_elapsed         | 257          |
# |    total_timesteps      | 92800        |
# | train/                  |              |
# |    approx_kl            | 5.412847e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 28990        |
# |    policy_gradient_loss | -0.000731    |
# |    value_loss           | 3.15e+08     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 2901        |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 92832       |
# | train/                  |             |
# |    approx_kl            | 3.87989e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.57e+08    |
# |    n_updates            | 29000       |
# |    policy_gradient_loss | -0.00022    |
# |    value_loss           | 3.15e+08    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2902          |
# |    time_elapsed         | 257           |
# |    total_timesteps      | 92864         |
# | train/                  |               |
# |    approx_kl            | 2.6375055e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 29010         |
# |    policy_gradient_loss | -0.000366     |
# |    value_loss           | 3.15e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 2903         |
# |    time_elapsed         | 257          |
# |    total_timesteps      | 92896        |
# | train/                  |              |
# |    approx_kl            | 2.577901e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 29020        |
# |    policy_gradient_loss | -0.000125    |
# |    value_loss           | 3.15e+08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 2904         |
# |    time_elapsed         | 257          |
# |    total_timesteps      | 92928        |
# | train/                  |              |
# |    approx_kl            | 9.126961e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 29030        |
# |    policy_gradient_loss | 5.13e-06     |
# |    value_loss           | 3.15e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2905          |
# |    time_elapsed         | 257           |
# |    total_timesteps      | 92960         |
# | train/                  |               |
# |    approx_kl            | 1.9744039e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.57e+08      |
# |    n_updates            | 29040         |
# |    policy_gradient_loss | -0.000229     |
# |    value_loss           | 3.15e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 2906          |
# |    time_elapsed         | 257           |
# |    total_timesteps      | 92992         |
# | train/                  |               |
# |    approx_kl            | 3.7122518e-06 |
# |    clip_fraction        | 0             |
# ...
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31040         |
# |    policy_gradient_loss | 0.000261      |
# |    value_loss           | 3.21e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3106          |
# |    time_elapsed         | 275           |
# |    total_timesteps      | 99392         |
# | train/                  |               |
# |    approx_kl            | 5.6810677e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31050         |
# |    policy_gradient_loss | -0.00012      |
# |    value_loss           | 3.21e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3107          |
# |    time_elapsed         | 275           |
# |    total_timesteps      | 99424         |
# | train/                  |               |
# |    approx_kl            | 2.3338944e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31060         |
# |    policy_gradient_loss | -0.000316     |
# |    value_loss           | 3.21e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3108          |
# |    time_elapsed         | 275           |
# |    total_timesteps      | 99456         |
# | train/                  |               |
# |    approx_kl            | 1.5255064e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31070         |
# |    policy_gradient_loss | -9.87e-06     |
# |    value_loss           | 3.21e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3109          |
# |    time_elapsed         | 275           |
# |    total_timesteps      | 99488         |
# | train/                  |               |
# |    approx_kl            | 3.1664968e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31080         |
# |    policy_gradient_loss | -0.000278     |
# |    value_loss           | 3.21e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 3110         |
# |    time_elapsed         | 275          |
# |    total_timesteps      | 99520        |
# | train/                  |              |
# |    approx_kl            | 9.460375e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.61e+08     |
# |    n_updates            | 31090        |
# |    policy_gradient_loss | -0.000741    |
# |    value_loss           | 3.21e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3111          |
# |    time_elapsed         | 275           |
# |    total_timesteps      | 99552         |
# | train/                  |               |
# |    approx_kl            | 4.8782676e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31100         |
# |    policy_gradient_loss | -0.000447     |
# |    value_loss           | 3.21e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3112          |
# |    time_elapsed         | 275           |
# |    total_timesteps      | 99584         |
# | train/                  |               |
# |    approx_kl            | 3.9879233e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31110         |
# |    policy_gradient_loss | -0.000391     |
# |    value_loss           | 3.21e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3113          |
# |    time_elapsed         | 275           |
# |    total_timesteps      | 99616         |
# | train/                  |               |
# |    approx_kl            | 2.4028122e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31120         |
# |    policy_gradient_loss | -0.000244     |
# |    value_loss           | 3.21e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3114          |
# |    time_elapsed         | 275           |
# |    total_timesteps      | 99648         |
# | train/                  |               |
# |    approx_kl            | 1.7918646e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31130         |
# |    policy_gradient_loss | -0.000128     |
# |    value_loss           | 3.22e+08      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 3115        |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 99680       |
# | train/                  |             |
# |    approx_kl            | 6.35162e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.61e+08    |
# |    n_updates            | 31140       |
# |    policy_gradient_loss | 5.23e-06    |
# |    value_loss           | 3.22e+08    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 3116        |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 99712       |
# | train/                  |             |
# |    approx_kl            | 1.73226e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.61e+08    |
# |    n_updates            | 31150       |
# |    policy_gradient_loss | -0.000298   |
# |    value_loss           | 3.22e+08    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3117          |
# |    time_elapsed         | 276           |
# |    total_timesteps      | 99744         |
# | train/                  |               |
# |    approx_kl            | 3.7755817e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31160         |
# |    policy_gradient_loss | -0.000363     |
# |    value_loss           | 3.22e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3118          |
# |    time_elapsed         | 276           |
# |    total_timesteps      | 99776         |
# | train/                  |               |
# |    approx_kl            | 1.6056001e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31170         |
# |    policy_gradient_loss | -0.000135     |
# |    value_loss           | 3.22e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 3119         |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 99808        |
# | train/                  |              |
# |    approx_kl            | 2.529472e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.61e+08     |
# |    n_updates            | 31180        |
# |    policy_gradient_loss | -0.000403    |
# |    value_loss           | 3.22e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3120          |
# |    time_elapsed         | 276           |
# |    total_timesteps      | 99840         |
# | train/                  |               |
# |    approx_kl            | 1.7601997e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31190         |
# |    policy_gradient_loss | -0.000104     |
# |    value_loss           | 3.22e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3121          |
# |    time_elapsed         | 276           |
# |    total_timesteps      | 99872         |
# | train/                  |               |
# |    approx_kl            | 2.7865171e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31200         |
# |    policy_gradient_loss | -0.000451     |
# |    value_loss           | 3.22e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3122          |
# |    time_elapsed         | 276           |
# |    total_timesteps      | 99904         |
# | train/                  |               |
# |    approx_kl            | 4.8168004e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31210         |
# |    policy_gradient_loss | -0.000339     |
# |    value_loss           | 3.22e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 3123         |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 99936        |
# | train/                  |              |
# |    approx_kl            | 2.587214e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.61e+08     |
# |    n_updates            | 31220        |
# |    policy_gradient_loss | -0.000186    |
# |    value_loss           | 3.22e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3124          |
# |    time_elapsed         | 276           |
# |    total_timesteps      | 99968         |
# | train/                  |               |
# |    approx_kl            | 4.8428774e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31230         |
# |    policy_gradient_loss | 4.33e-05      |
# |    value_loss           | 3.22e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 361           |
# |    iterations           | 3125          |
# |    time_elapsed         | 276           |
# |    total_timesteps      | 100000        |
# | train/                  |               |
# |    approx_kl            | 5.0105155e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.61e+08      |
# |    n_updates            | 31240         |
# |    policy_gradient_loss | -7.44e-05     |
# |    value_loss           | 3.22e+08      |
# -------------------------------------------

# %%
model =PPO.load('ppo_solvent')
obs = env.reset()

time_steps = 0
done = False

while not done:
    action, _states = model.predict(obs)  # Get the agent's action
    obs, reward, done, info = env.step(action) # Apply the action
    time_steps += 1

time_in_minutes = time_steps * 5  # each step corresponds to 5 minutes
print(f"Time required to reach x_reac <= 10.62: {time_in_minutes} minutes")
